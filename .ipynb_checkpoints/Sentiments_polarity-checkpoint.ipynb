# %%
import pandas as pd
import os
from nltk.tokenize import word_tokenize # For tokenization
from nltk.corpus import stopwords # For stopwords removal
from nltk.stem.wordnet import WordNetLemmatizer # For noise removal
from gensim import corpora
import gensim
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer as sia
import datetime

# %%
data = pd.read_csv('final.csv')
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,6,33,34,35,106,107) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#             REVIEW_ID           MEMBER_ID                        NPSCLINIC__C  \
# 0  a2p1U000000RoK0QAK  0011U00000riNolQAE        Arvada City of Arvada Clinic
# 1  a2p3g000000LAe2AAG  0011U00000riuzfQAA  Seven Hills Lombardo Center Clinic
# 2  a2p3g000000LAenAAG  0011U00000rieIYQAY           Monroe Campus Park Clinic
# 3  a2p1U000000l8FEQAY  0011U00000rjZH9QAM       Akron-White Pond Drive Clinic
# 4  a2p1U000000Rv9VQAS  0011U00000rjesHQAQ      Euclid Lincoln Electric Clinic
#
#   APPOINTMENTPROVIDER__C SURVEYDATE__C SURVEY_MONTH SURVEY_YEAR  \
# 0                    NaN    07-09-2018       Jul-18        2018
# 1     0031U00000olN5ZQAU    07-01-2020       Jul-20        2020
# 2     0031U00000olN7aQAE     6/27/2020       Jun-20        2020
# 3     0031U00000olN71QAE    10/25/2019       Oct-19        2019
# 4     0031U00000olN8YQAU     9/24/2019       Sep-19        2019
#
#    SURVEYNUMBER__C  NPS                                  REASONNPSSCORE__C  \
# 0            20536   10                                                NaN
# 1      11752005028    5                                                NaN
# 2      11737091171   10                                                NaN
# 3            31790   10                                                NaN
# 4            31283    8  I like the facility and the doctor.  I felt co...
#
#    ... positive_score negative_score sentiment sentiment_label  nps_label  \
# 0  ...          0.677          0.323         1        Positive   Promoter
# 1  ...          0.000          1.000         0         Neutral  Detractor
# 2  ...          0.000          1.000         0         Neutral   Promoter
# 3  ...          0.000          1.000         0         Neutral   Promoter
# 4  ...          0.169          0.831         1        Positive    Passive
#
#                           CLIENT NAME                  PARENT CLIENT NAME  \
# 0                   State of Colorado                   State of Colorado
# 1  Cleveland Bakers & Teamsters (CBT)  Cleveland Bakers & Teamsters (CBT)
# 2                        Union County                        Union County
# 3  Cleveland Bakers & Teamsters (CBT)  Cleveland Bakers & Teamsters (CBT)
# 4                    Lincoln Electric                    Lincoln Electric
#
#      PARENT_CLIENT_ID MEMBER_DOB MEMBER_STREET
# 0  0011U00000rhpLpQAI        NaN           NaN
# 1  0011U00000rhpN6QAI        NaN           NaN
# 2  0011U00000rhpLjQAI        NaN           NaN
# 3  0011U00000rhpN6QAI        NaN           NaN
# 4  0011U00000rhpMwQAI        NaN           NaN
#
# [5 rows x 108 columns]

# %%
# Remove entries with no response and remove punctuations
data_reason_score = data[data['reviews'] != 'No Response']
data_reason_score = data_reason_score.reset_index(drop=True)
remove_punctuations_reason_score = data_reason_score[['reviews']]
remove_punctuations_reason_score.replace("[^a-zA-Z]"," ",regex=True, inplace=True)
data_reason_score[['reviews']] = remove_punctuations_reason_score[['reviews']]
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
# Removing missing values
reason_score_reviews = data_reason_score
reason_score_reviews = reason_score_reviews.dropna(subset=['reviews'])
reason_score_reviews = reason_score_reviews.reset_index(drop=True)

# %%
# Converting reviews to lower case
reason_score_lower = reason_score_reviews[['reviews']]
reason_score_reviews['reviews'] = reason_score_lower.applymap(str.lower)

# %% [markdown]
# ## Sentiment

# %%
# Finding polarity score for each feedback
# It will show the polarity scores (positive, negative, neutral, and compound) for each feedback along with the feedback received
# Polarity scores will then be inserted into a list which will be accessed later to compute sentiment scores
reason_score_polarity_score_list = []

for each in reason_score_reviews.reviews:
    polarity_score = sia().polarity_scores(each)
    polarity_score['label'] = each
    reason_score_polarity_score_list.append(polarity_score)

# %%
reason_score_polarity_score_list
# Out:
# [{'neg': 0.0,
#   'neu': 0.323,
#   'pos': 0.677,
#   'compound': 0.8874,
#   'label': 'nan very kind and caring  provide comfortable seats'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan nan answer all my questions'},
#  {'neg': 0.0,
#   'neu': 0.831,
#   'pos': 0.169,
#   'compound': 0.9042,
#   'label': 'i like the facility and the doctor   i felt comfortable and felt like the doctor took time with me  greeting me   discussing all the issues i wanted to    i didn     t feel rushed    i had my appt  and med within a hour  make sure the customer knows where you called the prescription into   i     ve moved a lot and had several pharmacy     s    i verified before i left the appt '},
#  {'neg': 0.0,
#   'neu': 0.748,
#   'pos': 0.252,
#   'compound': 0.659,
#   'label': 'nan very caring staff   plenty of time for me to ask questions and get straight forward answers  nothing '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.067,
#   'neu': 0.61,
#   'pos': 0.324,
#   'compound': 0.8514,
#   'label': 'nan dr   was very good   listened to my concerns  was helpful  explained everything   very pleased with her  the nurse seemed like i was a bother to her '},
#  {'neg': 0.0,
#   'neu': 0.859,
#   'pos': 0.141,
#   'compound': 0.5574,
#   'label': 'nan dr  ritter answered all my questions and addressed all of my concerns  laura was pleasant and efficient as well  i know either covid they have been stretched thin  but didnt take it out on me  nan'},
#  {'neg': 0.0,
#   'neu': 0.761,
#   'pos': 0.239,
#   'compound': 0.765,
#   'label': 'nan everything    dr gray listened and offered feedback i never felt rushed i had an awesome appt  thank you vant think of anything'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.455,
#   'pos': 0.545,
#   'compound': 0.7184,
#   'label': 'nan everyone was friendly and efficient nothing'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan scheduling  diagnosis and recommendations none'},
#  {'neg': 0.0,
#   'neu': 0.769,
#   'pos': 0.231,
#   'compound': 0.2023,
#   'label': 'nan personal experience always top notch nan'},
#  {'neg': 0.0,
#   'neu': 0.677,
#   'pos': 0.323,
#   'compound': 0.9581,
#   'label': 'nan from the moment i enter the doctor officer i felt welcoming and dr pearl was amasing  she made me felt comfort and at ease  even to the nurse assistant was friendly and did a great job not forgeting they were very informative  no complain   you give did everything well for me '},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan thorough nan'},
#  {'neg': 0.0,
#   'neu': 0.669,
#   'pos': 0.331,
#   'compound': 0.8555,
#   'label': 'nan everyone was friendly and the doc has great bedside manners  i can     t think of anything that wasn     t done well '},
#  {'neg': 0.0,
#   'neu': 0.494,
#   'pos': 0.506,
#   'compound': 0.802,
#   'label': 'nan friendly and professional staff clean and calm waiting room nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan informative nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.545,
#   'pos': 0.455,
#   'compound': 0.9638,
#   'label': 'nan the staff and provider were caring  kind and compassionate  it was as if i was visiting with a trusted friend  loved it keep doing what you are doing nan'},
#  {'neg': 0.0,
#   'neu': 0.526,
#   'pos': 0.474,
#   'compound': 0.9451,
#   'label': 'nan april has a way of making you feel relaxed  and i appreciate how kind  caring  and professional she is  everything was excellent '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.518,
#   'pos': 0.482,
#   'compound': 0.8519,
#   'label': 'nan swift and courteous professional service and staff paladina the best    n a'},
#  {'neg': 0.0,
#   'neu': 0.89,
#   'pos': 0.11,
#   'compound': 0.6369,
#   'label': 'nan i love that my doctor spends time with me and follows up on things we talked about during my last appointment  i never feel rushed  which is why i left my last doctor  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan due to health issues i was experiencing  i really needed to speak to kim spencer rather early in the morning  as she is who i see most for appointments  i need to guidance as to what medical attention i needed to take  and i was quickly able to connect with her for direction and further medical instruction   kim was was quick to get back to me along with seeing me scheduled to see dr  mccay later that afternoon  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan dr lee called me early and we were quickly able to determine what was needed for our phone consultation  dr lee wasn     t initially aware of why she was calling me  needed her to fill out a form for blood donations regarding my health  '},
#  {'neg': 0.0,
#   'neu': 0.612,
#   'pos': 0.388,
#   'compound': 0.6908,
#   'label': 'nan vision test discussion on my condition ms always excellent service'},
#  {'neg': 0.03,
#   'neu': 0.878,
#   'pos': 0.092,
#   'compound': 0.8689,
#   'label': 'went in to have eye checked for possible corneal abrasion    when they got the kit to check  they realized they did not have the stain necessary to do so   since the only kit they had was the incomplete kit  it was a waste of time to go in  they said they did not know when the supplies would be in  needed to make arrangements to get help elsewhere    did not offer the service care promised in the timely fashion promised when paladina services were pitched to us  got appointment easily enough without needed to wait  unfortunately  even though they knew what was needed for my appointment when i called to make the appointment that morning  they did not have the necessary supplies to provide the services needed  was unable to get treatment or help when i arrived as the office did not have the needed supplies even though they knew what was needed when i called to make the appointment '},
#  {'neg': 0.0,
#   'neu': 0.591,
#   'pos': 0.409,
#   'compound': 0.8225,
#   'label': 'nan excellent doctor patient interaction loved the new rn that was on zip'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan addressed all my issues and concerns  n a'},
#  {'neg': 0.111,
#   'neu': 0.779,
#   'pos': 0.111,
#   'compound': 0.0,
#   'label': 'nan appointment started right on time  doctor was thorough and interested in finding out about any problems i was having  nothing'},
#  {'neg': 0.101,
#   'neu': 0.752,
#   'pos': 0.147,
#   'compound': 0.2429,
#   'label': 'nan dr e is always so kind and takes the time to listen and process before responding  i am so grateful for your kind care  the gal at the front desk is never very kind but hey i can     t imagine having to interact with that many sick people everyday so i get it '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.047,
#   'neu': 0.808,
#   'pos': 0.145,
#   'compound': 0.7501,
#   'label': 'nan everything went well   i walked up early monday morning and was able to get an appointment for four hours later   my appointment started on time and the doctor asked a lot of questions to nail down what was wrong   this is an incredible benefit to humana employees  nothing   there is nothing to say  it was great '},
#  {'neg': 0.052,
#   'neu': 0.601,
#   'pos': 0.348,
#   'compound': 0.7845,
#   'label': 'nan dr  thomas is a great listener and i always leave feeling like she understands my concerns  nan'},
#  {'neg': 0.0,
#   'neu': 0.588,
#   'pos': 0.412,
#   'compound': 0.923,
#   'label': 'nan kim and dr carrie are both caring and compassionate  i always have a good experience and am very thankful for them  nan'},
#  {'neg': 0.098,
#   'neu': 0.664,
#   'pos': 0.238,
#   'compound': 0.5574,
#   'label': 'nan i have difficult veins to draw blood from and they     re always patient and kind which i appreciate  nan'},
#  {'neg': 0.276,
#   'neu': 0.724,
#   'pos': 0.0,
#   'compound': -0.4939,
#   'label': 'nan todo  no tengo la m atilde  shy nima queja todo  estuvo bien'},
#  {'neg': 0.0,
#   'neu': 0.879,
#   'pos': 0.121,
#   'compound': 0.5859,
#   'label': 'nan the doctor and the staff spent a lot of time with me and made sure i had all of my concerns addressed  i didn     t feel rushed  i felt like the appointment was very thorough  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.56,
#   'pos': 0.44,
#   'compound': 0.7414,
#   'label': 'nan everything   staff are very professional  caring  and helpful  nan'},
#  {'neg': 0.0,
#   'neu': 0.747,
#   'pos': 0.253,
#   'compound': 0.8702,
#   'label': 'nan it is so easy to get in contact with my physicians   same day phone calls make it easy to assess whether you need to go into the office for care  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.856,
#   'pos': 0.144,
#   'compound': 0.5198,
#   'label': 'nan on time  very thorough  very helpful  find right pharmacy  i     ll let them know walmart neighborhood does have a pharmacy '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.868,
#   'pos': 0.132,
#   'compound': 0.4939,
#   'label': 'nan it was quick  on time  friendly  and very informative  i had to wait several weeks before i could get an appointment '},
#  {'neg': 0.0,
#   'neu': 0.838,
#   'pos': 0.162,
#   'compound': 0.6136,
#   'label': 'nan receptionist was welcoming and knowledgeable that i was coming in  doctor was thorough in discussing all of my medical issues i cant complain about anything in particular'},
#  {'neg': 0.0,
#   'neu': 0.768,
#   'pos': 0.232,
#   'compound': 0.8957,
#   'label': 'i have only had one visit with paladina   so far it seems good  doctor was on time and spent a lot of time with me   i felt he was caring and trustworthy  there was nothing that wasn     t done well during my appointment '},
#  {'neg': 0.173,
#   'neu': 0.598,
#   'pos': 0.229,
#   'compound': 0.4023,
#   'label': 'nan everything that no other doctor has done before  all of the above    excellent care  and customer service nothing  everything was perfect '},
#  {'neg': 0.051,
#   'neu': 0.716,
#   'pos': 0.233,
#   'compound': 0.7964,
#   'label': 'nan everyone was great during my visit  even with emr issues  the visit was excellent  i     m seriously considering switching dr  mccay to be my pcp  nan'},
#  {'neg': 0.129,
#   'neu': 0.478,
#   'pos': 0.394,
#   'compound': 0.8718,
#   'label': 'great nurses  great office  only complaint is dr thomas has somewhat inconvenient office hours  friendly  prompt staff and doctor  everything went fine'},
#  {'neg': 0.164,
#   'neu': 0.836,
#   'pos': 0.0,
#   'compound': -0.2878,
#   'label': 'not very convenient with limited time availability nan meet all my requests'},
#  {'neg': 0.0,
#   'neu': 0.859,
#   'pos': 0.141,
#   'compound': 0.7845,
#   'label': 'nan ask me general and specialized questions to know what exactly was going on  went through the process of elimination to find out the best treatment option for me and explained in common terms to help me understand what we will be doing  nan'},
#  {'neg': 0.0,
#   'neu': 0.811,
#   'pos': 0.189,
#   'compound': 0.743,
#   'label': 'nan i love that my doctor takes time to really listen to my concerns and needs and will address them in a manner that works well for me  nothing'},
#  {'neg': 0.0,
#   'neu': 0.722,
#   'pos': 0.278,
#   'compound': 0.6124,
#   'label': 'nan my appointment     s always go well for me and my family  thanks  n a'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan everything nothing'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.051,
#   'neu': 0.791,
#   'pos': 0.158,
#   'compound': 0.5541,
#   'label': 'nan paula and stephanie are amazing  your an actual person with them and not just a number on a chart  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.138,
#   'neu': 0.776,
#   'pos': 0.087,
#   'compound': -0.5535,
#   'label': 'the doctors at my clinic always do the absolute least amount of care possible  even when it is clear that testing might be warranted for diagnosis  they won     t even do screening tests  they quickly  and not thoughtfully  come to a conclusion without giving the benefit of the doubt that a problem might not be just superficial  you returned my call in a timely manner  you didn     t actually listen to my concerns  rather you decided what was wrong with me before knowing all the symptoms and circumstances surrounding the onset of my symptoms '},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan listened nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan answered all of my questions nothing'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.629,
#   'pos': 0.371,
#   'compound': 0.7579,
#   'label': 'nan the doctor is always pleasant and through  receptionist is alwas friendly  nothing'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.017,
#   'neu': 0.894,
#   'pos': 0.088,
#   'compound': 0.7568,
#   'label': 'nan everything was handled well from scheduling to check in to the appointment itself   very much appreciated  the only point of confusion was that i was told on the phone i had an   am appointment  but email and website communications indicated a       appointment   ultimately  i got there in time for a       appointment  but was told it was really at      however  i was back in a room by        so it was better time than i ever would have seen from any other doctor i     ve visited before '},
#  {'neg': 0.0,
#   'neu': 0.883,
#   'pos': 0.117,
#   'compound': 0.6908,
#   'label': 'nan appreciated the time jera and dr  leahy took to hear my concerns and assess my conditions i didn acirc  euro  trade t revive a written summary of my visit which needs to include follow up testing instructions  i had to call the office back '},
#  {'neg': 0.091,
#   'neu': 0.524,
#   'pos': 0.385,
#   'compound': 0.8555,
#   'label': 'nan offered great care  flu shot   was very informative regarding my health needs and habits  overall  excellent experience  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan consult with doctor and lab tests  nan'},
#  {'neg': 0.0,
#   'neu': 0.734,
#   'pos': 0.266,
#   'compound': 0.4404,
#   'label': 'nan everything was good they were a little late'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan explained situation that i have showed online options to assist me with exercises  na'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.825,
#   'pos': 0.175,
#   'compound': 0.6486,
#   'label': 'nan i feel like i always have dr dealleaume     s complete attention  i had just had surgery and it was nice to get answers to things  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.589,
#   'pos': 0.411,
#   'compound': 0.5413,
#   'label': 'nan very caring  quick  listened nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan conversation nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan check up due to meds everything was done'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.837,
#   'pos': 0.163,
#   'compound': 0.5106,
#   'label': 'nan enjoyed meeting with the doctor and staff  this appointment was to establish with a new doctor nothing'},
#  {'neg': 0.403,
#   'neu': 0.597,
#   'pos': 0.0,
#   'compound': -0.4019,
#   'label': 'nan understand my illness nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.523,
#   'pos': 0.477,
#   'compound': 0.8074,
#   'label': 'nan showed great care and concern for my issue  nan'},
#  {'neg': 0.0,
#   'neu': 0.688,
#   'pos': 0.312,
#   'compound': 0.8434,
#   'label': 'most health care choices for my friends are not choices  rather what their work provides   just like paladina is for me  nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan listened to my needs and helped me  n a'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan listened nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan check up for cold cough n a'},
#  {'neg': 0.0,
#   'neu': 0.801,
#   'pos': 0.199,
#   'compound': 0.7351,
#   'label': 'nan made me feel welcome   dr  giles and margerita were both friendly and knowledgeable  i didn     t have to wait long at all for my appointment  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan everything nothing'},
#  {'neg': 0.0,
#   'neu': 0.773,
#   'pos': 0.227,
#   'compound': 0.8176,
#   'label': 'nan everyone was friendly and caring   explained everything to me and listened to my concerns set a plan to find answers  from scheduling to my appointment and tests all was handled well '},
#  {'neg': 0.0,
#   'neu': 0.691,
#   'pos': 0.309,
#   'compound': 0.7717,
#   'label': 'nan paid attention to my input and my medical history   appeared knowledgeable   kind  courteous and personable nan'},
#  {'neg': 0.0,
#   'neu': 0.872,
#   'pos': 0.128,
#   'compound': 0.4215,
#   'label': 'nan i liked that dr  mccay spent a lot of time with me explaining things to me in depth  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan initial appointment nothing'},
#  {'neg': 0.102,
#   'neu': 0.739,
#   'pos': 0.159,
#   'compound': 0.5267,
#   'label': 'the staff is nice and spend more time with you  the blood draw hurt my daughter      and they were short of shingles vaccine  but other than that  they did a good job  extra time with doctor was nice  blood draw was a bit painful for my    year old daughter '},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan yearly exam nan'},
#  {'neg': 0.048,
#   'neu': 0.477,
#   'pos': 0.475,
#   'compound': 0.8676,
#   'label': 'nan staff is always nice and welcoming  i leave there feeling like my concerns were addressed  no complaints'},
#  {'neg': 0.0,
#   'neu': 0.601,
#   'pos': 0.399,
#   'compound': 0.932,
#   'label': 'nan awesome interaction with the front office person and the np  very nice people  took their time and were very attentive  overall great experience  nan'},
#  {'neg': 0.0,
#   'neu': 0.625,
#   'pos': 0.375,
#   'compound': 0.9153,
#   'label': 'nan i liked that when i passed out the staff was responsive and made sure that i had everything that i needed to feel safe and comfortable  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.759,
#   'pos': 0.241,
#   'compound': 0.624,
#   'label': 'nan i really appreciate everything  paladina in general as well as this clinic  kathleen and dr  masterson  nada '},
#  {'neg': 0.0,
#   'neu': 0.734,
#   'pos': 0.266,
#   'compound': 0.4404,
#   'label': 'nan quick and easy given the virtual platform nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'i don     t know many people who don     t have paladina  physical  nan'},
#  {'neg': 0.0,
#   'neu': 0.608,
#   'pos': 0.392,
#   'compound': 0.9217,
#   'label': 'good access to doctor and caring service providers worked well to provide follow up care to recent hospitalization i was satisfied with all aspects of the visit'},
#  {'neg': 0.0,
#   'neu': 0.553,
#   'pos': 0.447,
#   'compound': 0.9179,
#   'label': 'nan dr  plunk was wonderful to work with  she was kind  listened  and even made me laugh no complaints here'},
#  {'neg': 0.0,
#   'neu': 0.556,
#   'pos': 0.444,
#   'compound': 0.4939,
#   'label': 'nan friendly and polite nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan very thorough the ekg machine wasn     t working'},
#  {'neg': 0.061,
#   'neu': 0.831,
#   'pos': 0.108,
#   'compound': 0.2732,
#   'label': 'nan the attentiveness from np jenna and ma georgia were exemplary   np made herself familiar with my medical history before office visit   she listened to all my chief complaints  voiced her concerns  and together we devised a treatment plan  nan'},
#  {'neg': 0.0,
#   'neu': 0.828,
#   'pos': 0.172,
#   'compound': 0.4404,
#   'label': 'nan explained thoroughly the results of my blood work and performed a good physical nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan helped me nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.701,
#   'pos': 0.299,
#   'compound': 0.9363,
#   'label': 'nan the appointment started on time and every staff member was friendly and professional  the space was very clean and easy to find  labs were completed on site  i am so grateful to have found this place  everything was done well '},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan gave me time to explain issues  and even asked about something unrelated to this visit nan'},
#  {'neg': 0.0,
#   'neu': 0.826,
#   'pos': 0.174,
#   'compound': 0.6115,
#   'label': 'nan dr  mckay is the most attentive doctor i     ve ever had   extremely happy with him as my provider  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.059,
#   'neu': 0.741,
#   'pos': 0.201,
#   'compound': 0.6808,
#   'label': 'nan i was able to schedule an appointment for suspected covid symptoms quickly and easily by calling the location located in the humana tower  everything was great '},
#  {'neg': 0.119,
#   'neu': 0.621,
#   'pos': 0.26,
#   'compound': 0.3591,
#   'label': 'didnt feel like a number getting passed on the whole experience was pleasant nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.562,
#   'pos': 0.438,
#   'compound': 0.8204,
#   'label': 'nan dr and staff are always very helpful  they treat you like family nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan they get right to the point  blood work and shoulder'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.779,
#   'pos': 0.221,
#   'compound': 0.5709,
#   'label': 'nan this was my first visit at paladina and everyone was very kind  nan'},
#  {'neg': 0.141,
#   'neu': 0.619,
#   'pos': 0.24,
#   'compound': 0.6115,
#   'label': 'nan the doctor was really wonderful and seemed to enjoy her job  she made me feel like a rock star  i don     t have anything bad to say  no issues '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.106,
#   'neu': 0.58,
#   'pos': 0.314,
#   'compound': 0.6486,
#   'label': 'friendly   pleasant and spend time   no rush in and rush out answers my questions nan'},
#  {'neg': 0.0,
#   'neu': 0.695,
#   'pos': 0.305,
#   'compound': 0.8481,
#   'label': 'nan megan plunk is amazing  she spent the right amount of time with me and gave me lots of good information  thank you  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.951,
#   'pos': 0.049,
#   'compound': 0.1779,
#   'label': 'nan the nurse listen to my issues  and communicated the issues correctly to the doctor    the doctor was open to me about my issues  and gave me several possible solutions  none at this time'},
#  {'neg': 0.0,
#   'neu': 0.836,
#   'pos': 0.164,
#   'compound': 0.6705,
#   'label': 'nan the clinic was clean  staff professional and polite during my appointment  it would been helpful to book a appointment for first  instead of have to do phone interview first '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.703,
#   'pos': 0.297,
#   'compound': 0.8016,
#   'label': 'nan excellent  quot bedside quot  manner  the staff was very friendly and was very patient with my ramblings nan'},
#  {'neg': 0.0,
#   'neu': 0.641,
#   'pos': 0.359,
#   'compound': 0.4215,
#   'label': 'nan attentive  efficient and informative nan'},
#  {'neg': 0.0,
#   'neu': 0.809,
#   'pos': 0.191,
#   'compound': 0.5106,
#   'label': 'nan attentive physicians  courteous staff  quick in and quick out  physician answered all questions  nan'},
#  {'neg': 0.129,
#   'neu': 0.528,
#   'pos': 0.343,
#   'compound': 0.5653,
#   'label': 'nan no rushing  always feel comfortable with my dr  nothing went wrong'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.522,
#   'pos': 0.478,
#   'compound': 0.6705,
#   'label': 'nan clear information and good customer service nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan everything nothing'},
#  {'neg': 0.0,
#   'neu': 0.496,
#   'pos': 0.504,
#   'compound': 0.8795,
#   'label': 'nan got an appointment quickly  i received very caring an compassionate care  nan'},
#  {'neg': 0.0,
#   'neu': 0.536,
#   'pos': 0.464,
#   'compound': 0.8247,
#   'label': 'nan they treated me very well and everything was perfect  nothing was wrong'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan everything nan'},
#  {'neg': 0.0,
#   'neu': 0.822,
#   'pos': 0.178,
#   'compound': 0.3818,
#   'label': 'nan the explanation of all of the benefits of going through palladina nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.501,
#   'pos': 0.499,
#   'compound': 0.7889,
#   'label': 'nan everyone was really nice  positive and very professional           '},
#  {'neg': 0.0,
#   'neu': 0.372,
#   'pos': 0.628,
#   'compound': 0.7755,
#   'label': 'nan very respectful and caring nan'},
#  {'neg': 0.0,
#   'neu': 0.549,
#   'pos': 0.451,
#   'compound': 0.6249,
#   'label': 'nan great nurse and convenient na'},
#  {'neg': 0.0,
#   'neu': 0.738,
#   'pos': 0.262,
#   'compound': 0.4939,
#   'label': 'nan convenient and quality care forgot to fill a rx'},
#  {'neg': 0.0,
#   'neu': 0.714,
#   'pos': 0.286,
#   'compound': 0.8313,
#   'label': 'nan dr  gorman always makes me feel welcome and is genuinely concerned when listening to my symptoms  he is professional  helpful  and very calming  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.462,
#   'pos': 0.538,
#   'compound': 0.5413,
#   'label': 'nan very friendly nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan i was able to be seen the same day  nan'},
#  {'neg': 0.106,
#   'neu': 0.894,
#   'pos': 0.0,
#   'compound': -0.357,
#   'label': 'nan answered my questions  let me know what to expect and when to call back if i did not see improvement nan'},
#  {'neg': 0.0,
#   'neu': 0.761,
#   'pos': 0.239,
#   'compound': 0.7635,
#   'label': 'nan dr mckay takes the time to understand the patient and the situation   it     s obvious that he cares  very much appreciated  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.044,
#   'neu': 0.671,
#   'pos': 0.286,
#   'compound': 0.8519,
#   'label': 'nan great professional and caring environment  thank you  tough getting an appetite scheduled  rescheduled   times and i will still need another rescheduled appointment to see my doc '},
#  {'neg': 0.0,
#   'neu': 0.717,
#   'pos': 0.283,
#   'compound': 0.8519,
#   'label': 'nan the dr and staff is great  and i will not go any where else  i just love them   they did everything right '},
#  {'neg': 0.0,
#   'neu': 0.669,
#   'pos': 0.331,
#   'compound': 0.9466,
#   'label': 'nan my dr is always great and caring she take the time and listen to you  and you and talk to her  i am so glad i have her has my dr  love paladina  everything'},
#  {'neg': 0.0,
#   'neu': 0.654,
#   'pos': 0.346,
#   'compound': 0.5719,
#   'label': 'nan everything was perfect and very helpfull nan'},
#  {'neg': 0.057,
#   'neu': 0.731,
#   'pos': 0.212,
#   'compound': 0.8443,
#   'label': 'nan dr  johnson listened  provided good advice on everything i asked about  and did a thorough check in on my overall health  it really felt like she cared about my wellbeing and spending quality time with me  nothing  i love paladina and was so impressed with dr  johnson '},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan everything from scheduling appt to visit with the dr  nothing'},
#  {'neg': 0.041,
#   'neu': 0.887,
#   'pos': 0.072,
#   'compound': 0.6486,
#   'label': 'nan there was no one else in the waiting room  there was no waiting for the doctor  the doctor came in promptly  i had plenty of time to ask questions and ponder various ailments in a holistic way with the doctor  since paladina is trying hard to disrupt standard medical care  i was hoping you had disrupted the standard tedium of filling out a multi page paper form before seeing the doctor   i could have done that online before my visit     if that had been an option   i don     t really expect this from any medical practice  but it would nice '},
#  {'neg': 0.041,
#   'neu': 0.911,
#   'pos': 0.047,
#   'compound': -0.1154,
#   'label': 'nan my doctor is first rate and knows how to conduct a phone examination  the appointment didn     t start on time because the videoconferencing technology used didn     t work  i attempted to connect via desktop  chrome and firefox on linux     which should work just as they would on windows or macos but which are  i believe  arbitrarily banned    and via an emailed link on my iphone  using safari for ios  in sum  the technology isn     t robust enough for purpose  facetime  or any of a number of other technologies  beat it '},
#  {'neg': 0.0,
#   'neu': 0.651,
#   'pos': 0.349,
#   'compound': 0.9081,
#   'label': 'nan on time and even early for seeing me  appreciated giving me water when i arrived  didn     t feel welcomed at first took a while to feel safe and welcomed '},
#  {'neg': 0.057,
#   'neu': 0.634,
#   'pos': 0.309,
#   'compound': 0.8979,
#   'label': 'nan staff and dr  made you feel like your best interest was being addressed  i like they review you appt and time was take to hear all concerns along with problem solving  cannot think of anything '},
#  {'neg': 0.0,
#   'neu': 0.908,
#   'pos': 0.092,
#   'compound': 0.7089,
#   'label': 'nan one on one time with the doctor wasn     t rushed  everyone i interacted with was helpful and made me feel heard  it would have been a lot more helpful to know when i made my appointment that i would have to end up making an appointment at a travel clinic for vaccines i was unable to get at paladina '},
#  {'neg': 0.0,
#   'neu': 0.792,
#   'pos': 0.208,
#   'compound': 0.2732,
#   'label': 'nan all was well  nothing in particular  n a '},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'saves money doctor  listen to what i had to say about my health  nan'},
#  {'neg': 0.0,
#   'neu': 0.723,
#   'pos': 0.277,
#   'compound': 0.4703,
#   'label': 'nan dr  cook is very attentive and helpful nan'},
#  {'neg': 0.0,
#   'neu': 0.69,
#   'pos': 0.31,
#   'compound': 0.6046,
#   'label': 'friendly   timely    not stuck waiting in waiting room a  long time  nan nan'},
#  {'neg': 0.022,
#   'neu': 0.796,
#   'pos': 0.183,
#   'compound': 0.9753,
#   'label': 'nan i was roomed timely and seen by the doctor timely  the doctor spent more time than she needed with me  but i felt truly cared for by her and the ma  i was able to address issues that i have had for years that i     ve felt had been ignored by previous providers or i didn     t have the opportunity to discuss  i was given options for my care and felt valued  i showed up early to my appointment  i didn     t expect to get seen early  but i did hear the team chatting in the back  just a quick explanation that i wouldn     t get seen until my appointment time would have been great '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.568,
#   'pos': 0.432,
#   'compound': 0.9806,
#   'label': 'nan you did everything really well  everyone at this location is always so welcoming and kind  they are all a pleasure to work with  always so professional  kind and caring  everything was great  cannot think of anything that could have made it any better '},
#  {'neg': 0.022,
#   'neu': 0.7,
#   'pos': 0.279,
#   'compound': 0.9948,
#   'label': 'nan you did everything right  from the moment i entered the door   i was welcomed and greeted with a smile and  in less than no time  i was escorted to the examination room where once again  the nurse in attendance could not have been kinder or more caring   dr  curtis was great   very thoughtful and thorough with regard to my examination and  was extremely caring  courteous and very professional    he was just the best in every way   he asked all the right questions and i could not have felt more comfortable or more certain that i had made the right choice for my health care and i am so very appreciative that i have dr  curtis in my corner  thank you dr  curtis  thank you so very much  i cannot think of anything that could have been done or said that was not   it was a great experience and i consider myself and my wife very fortunate to be patients of dr  curtis and his great staff '},
#  {'neg': 0.077,
#   'neu': 0.564,
#   'pos': 0.359,
#   'compound': 0.9179,
#   'label': 'nan dr  fairbanks was incredibly caring and supportive   i feel like i     m in crisis and she offered support  listened  asked questions   i really couldn     t have felt better about the appointment and ongoing care she recommended  nan'},
#  {'neg': 0.0,
#   'neu': 0.717,
#   'pos': 0.283,
#   'compound': 0.8063,
#   'label': 'nan gave me all the info i needed they are very helpful i really like dr boyer and staff they did everything very well'},
#  {'neg': 0.0,
#   'neu': 0.6,
#   'pos': 0.4,
#   'compound': 0.9326,
#   'label': 'nan doctor bernardy is the best  she is the best doctor i ever had  knowledgeable and friendly  no harsh judgement on life choices  n a'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan addressing any issues or concerns nan'},
#  {'neg': 0.0,
#   'neu': 0.729,
#   'pos': 0.271,
#   'compound': 0.836,
#   'label': 'nan i love paladina health   you guys do everything right   the way it should be done   i feel valued n important as a patient of paladina nan'},
#  {'neg': 0.0,
#   'neu': 0.805,
#   'pos': 0.195,
#   'compound': 0.7239,
#   'label': 'it     s location is conveniently close to work and the doctor spent a good amount of time addressing my concerns  a very thorough and considerate intake  nan'},
#  {'neg': 0.0,
#   'neu': 0.764,
#   'pos': 0.236,
#   'compound': 0.4754,
#   'label': 'nan listened  and give very helpful information  all needs were met '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.643,
#   'pos': 0.357,
#   'compound': 0.836,
#   'label': 'i was able to get in on time and i like the dr  friendly staff   i felt relaxed  nan'},
#  {'neg': 0.0,
#   'neu': 0.429,
#   'pos': 0.571,
#   'compound': 0.6115,
#   'label': 'nan very happy nan'},
#  {'neg': 0.0,
#   'neu': 0.824,
#   'pos': 0.176,
#   'compound': 0.4576,
#   'label': 'nan i really appreciate k hathaway    i brag about her to all my collegues nan'},
#  {'neg': 0.063,
#   'neu': 0.694,
#   'pos': 0.243,
#   'compound': 0.8316,
#   'label': 'staff at trail head clinic in grand junction staff at the clinic was awesome was scheduled to the wrong clinic by paladina   trail head was able to fit me in and made sure i got to see the doctor '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.877,
#   'pos': 0.123,
#   'compound': 0.4215,
#   'label': 'it was nice not to be rushed during the appointment taking the time to listen and getting to know me nan'},
#  {'neg': 0.0,
#   'neu': 0.712,
#   'pos': 0.288,
#   'compound': 0.8847,
#   'label': 'nan very friendly staff   as soon as i arrived i was taken back immediately for vitals and then checked into the exam room   the np came very promptly   very efficient practice  nan'},
#  {'neg': 0.0,
#   'neu': 0.696,
#   'pos': 0.304,
#   'compound': 0.5859,
#   'label': 'nan everyone treated me professionally yet warmly  everything went well at this appointment '},
#  {'neg': 0.0,
#   'neu': 0.849,
#   'pos': 0.151,
#   'compound': 0.6908,
#   'label': 'nan i always like how friendly everyone is when i come there   they take the time to listen to what i have to say and they don     t rush you in and out  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.752,
#   'pos': 0.248,
#   'compound': 0.9501,
#   'label': 'nan dr  mccay really takes the time to go thru my concerns and spends the time following up with our past discussions as well  i truly feel like he genuinely cares about my wellbeing and puts time into making a plan to address my issues  i am very thankful to have him as my provider and i trust him       nan'},
#  {'neg': 0.0,
#   'neu': 0.414,
#   'pos': 0.586,
#   'compound': 0.7947,
#   'label': 'nan everything very friendly courteous professional nothing'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.777,
#   'pos': 0.223,
#   'compound': 0.3182,
#   'label': 'nan making sure to know the right cure nan'},
#  {'neg': 0.05,
#   'neu': 0.466,
#   'pos': 0.484,
#   'compound': 0.9423,
#   'label': 'nan wonderful service  i have a fair amount of patient anxiety and it was a great experience  great nurse and np nothing'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan yearly physical nothing'},
#  {'neg': 0.051,
#   'neu': 0.777,
#   'pos': 0.172,
#   'compound': 0.9093,
#   'label': 'i had a complicated start with paladina   my second start has been really good   kathleen hathaway and staff are helping me with a potential medical emergency   for me   having essentially   doctors my entire life  i am       and not a very good patient to be honest   having someone who actually takes the time and walks me through things is a really big deal  so  katy and staff have been a real blessing that i am very grateful for  i would recommend her to anyone to consider  covid test nothing'},
#  {'neg': 0.0,
#   'neu': 0.558,
#   'pos': 0.442,
#   'compound': 0.9816,
#   'label': 'nan tina does an excellent job taking my blood and giving vaccines  she made it as painless as possible  thank you for that  and always pleasant   dr  kaushal is the best  she listens to my concerns while helping me understand my meds  also very kind  no problems  everything was good '},
#  {'neg': 0.0,
#   'neu': 0.878,
#   'pos': 0.122,
#   'compound': 0.4939,
#   'label': 'doctor spends time with patient and is thorough with assessment and treatment  doctor also called patient to discuss patient concerns  friendly   professional  informative  na'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.76,
#   'pos': 0.24,
#   'compound': 0.8342,
#   'label': 'the service i received was great even though i work for the company  i was treated like a patient  not co worker i had no problem or issues with my appointment'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.043,
#   'neu': 0.907,
#   'pos': 0.05,
#   'compound': 0.0736,
#   'label': 'nan it all was handled well and quickly from making and scheduling appointments for that day plus a physical on a future date  the visit was quick too i do not have anything that did not go well last visit'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan i really feel the doctor and nurse listen to me and work with me  nan'},
#  {'neg': 0.021,
#   'neu': 0.71,
#   'pos': 0.269,
#   'compound': 0.9438,
#   'label': 'nan i did not feel rushed  every question i asked was answered with enthusiasm and respect  i felt cared for by both the nurse and doctor  i felt very safe being in the clinic  as i was the only patient at the time and not paranoid about feeling too crowded  everything was wonderful '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.08,
#   'neu': 0.92,
#   'pos': 0.0,
#   'compound': -0.1027,
#   'label': 'nan spent time to be thorough on everything it is hard to get an appointment by phone'},
#  {'neg': 0.0,
#   'neu': 0.225,
#   'pos': 0.775,
#   'compound': 0.7845,
#   'label': 'nan excellent care nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan it was quick and did not work nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.044,
#   'neu': 0.849,
#   'pos': 0.107,
#   'compound': 0.3182,
#   'label': 'good doctor  quick appointments  and convenient location for me  there was no waiting  and good pandemic practice was followed the blood draw was so so  with some needle adjustment required  but that happens sometimes '},
#  {'neg': 0.054,
#   'neu': 0.631,
#   'pos': 0.315,
#   'compound': 0.911,
#   'label': 'nan april always does a great job and is very friendly and courteous  it would be nice to be offered a copy of the warning waiver i had to sign for the medication '},
#  {'neg': 0.0,
#   'neu': 0.725,
#   'pos': 0.275,
#   'compound': 0.8016,
#   'label': 'nan the nurse and doctor were both very nice and the appointment didn     t feel rushed at all   great experience nan'},
#  {'neg': 0.0,
#   'neu': 0.426,
#   'pos': 0.574,
#   'compound': 0.6597,
#   'label': 'nan all good  thank you  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.508,
#   'pos': 0.492,
#   'compound': 0.4404,
#   'label': 'nan nan all good'},
#  {'neg': 0.0,
#   'neu': 0.878,
#   'pos': 0.122,
#   'compound': 0.2382,
#   'label': 'inexpensive  easy access  but revolving door physicians covered all the bases  professional  non condescending nan'},
#  {'neg': 0.0,
#   'neu': 0.455,
#   'pos': 0.545,
#   'compound': 0.8555,
#   'label': 'love this place love the doctor so thorough nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.834,
#   'pos': 0.166,
#   'compound': 0.4927,
#   'label': 'nan the nurse and assistant were prompt and had very good bedside manner  nothing comes to mind '},
#  {'neg': 0.0,
#   'neu': 0.766,
#   'pos': 0.234,
#   'compound': 0.7506,
#   'label': 'nan the dr  and the assistant were friendly and caring and took their time getting to know me and my medical concerns nothing'},
#  {'neg': 0.0,
#   'neu': 0.898,
#   'pos': 0.102,
#   'compound': 0.3612,
#   'label': 'nan i always feel like dr  walker conner is listening and takes the time to check on everything  both physically and emotionally  nothing'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.825,
#   'pos': 0.175,
#   'compound': 0.1779,
#   'label': 'nan listened to my concerns and offered solutions nan'},
#  {'neg': 0.131,
#   'neu': 0.787,
#   'pos': 0.082,
#   'compound': -0.4374,
#   'label': 'nan took time to consider my broader context  timeline  trend   examined me personally  apparently some detail of what we agreed for a special ultrasound was not clear in the notes  so we are following up to align on expectations with the ultrasound provider   patient caught the disconnect and avoided wrong scan  '},
#  {'neg': 0.043,
#   'neu': 0.728,
#   'pos': 0.229,
#   'compound': 0.882,
#   'label': 'the appointment was smooth and efficient  doing it online was not as strange as it initially seemed like it would be  everyone was very kind and respectful  we spoke about all of my concerns and i was given plenty of time to think about what may be bothering me  nan'},
#  {'neg': 0.0,
#   'neu': 0.898,
#   'pos': 0.102,
#   'compound': 0.2584,
#   'label': 'nan all caregivers spent time focusing on me and did not seem distracted by other things   they listened  nan'},
#  {'neg': 0.0,
#   'neu': 0.671,
#   'pos': 0.329,
#   'compound': 0.7089,
#   'label': 'nan you spent time listening to me and were very empathetic  all was good'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan explained everything that would be taking place during the visit  nan'},
#  {'neg': 0.0,
#   'neu': 0.643,
#   'pos': 0.357,
#   'compound': 0.9388,
#   'label': 'nan during the appointment everyone was courteous   very friendly and professional   all my questions were answer they made me feel comfortable it was a relaxing atmosphere  i have no complaints about my appointment '},
#  {'neg': 0.0,
#   'neu': 0.899,
#   'pos': 0.101,
#   'compound': 0.3089,
#   'label': 'nan it was explained to me the reason the office it     s closed and only phone conversation   i have no complaints '},
#  {'neg': 0.0,
#   'neu': 0.865,
#   'pos': 0.135,
#   'compound': 0.3612,
#   'label': 'nan took the time to listen and i didn     t feel like i was being rushed nan'},
#  {'neg': 0.0,
#   'neu': 0.872,
#   'pos': 0.128,
#   'compound': 0.4754,
#   'label': 'nan when i came in for my appointment  i did not need to wait long and the staff was very efficient  nan'},
#  {'neg': 0.0,
#   'neu': 0.773,
#   'pos': 0.227,
#   'compound': 0.6249,
#   'label': 'nan great bedside manner and got me on and out before my scheduled time ns'},
#  {'neg': 0.0,
#   'neu': 0.849,
#   'pos': 0.151,
#   'compound': 0.4939,
#   'label': 'nan took your time to take care of me and listen to what is going on with me  nan'},
#  {'neg': 0.061,
#   'neu': 0.753,
#   'pos': 0.186,
#   'compound': 0.7414,
#   'label': 'nan dr  fairbanks is thoughtful and caring and didn     t rush to a diagnosis  she asked questions and probed deeper to determine what was wrong  dr  fairbanks followed up with me a few days later and that is very much appreciated  nan'},
#  {'neg': 0.0,
#   'neu': 0.815,
#   'pos': 0.185,
#   'compound': 0.8122,
#   'label': 'nan i was able to have a phone appointment    and she was able to give me the help i needed    and i really appreciated it because i was leaving to go to texas in the next    hours everything went well'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
# ...
#  {'neg': 0.084,
#   'neu': 0.68,
#   'pos': 0.236,
#   'compound': 0.5859,
#   'label': 'nan you had time for me  when i was nervous about the spot   staff was both compassionate and empathetic  nan'},
#  {'neg': 0.0,
#   'neu': 0.417,
#   'pos': 0.583,
#   'compound': 0.7906,
#   'label': 'nan everything thanks for being great   nothing'},
#  {'neg': 0.074,
#   'neu': 0.839,
#   'pos': 0.088,
#   'compound': 0.1411,
#   'label': 'nan communication  moved in a timely fashion but not rushed  cared about the answers i gave and made me feel they were interested in what was going on in my life in regards to health  nan'},
#  {'neg': 0.16,
#   'neu': 0.84,
#   'pos': 0.0,
#   'compound': -0.5809,
#   'label': 'nan the dr not only took care of my purpose in coming but showed genuine concern when she learned that i had recently lost my brother  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan doctor listened to me explain my issue  nan'},
#  {'neg': 0.068,
#   'neu': 0.655,
#   'pos': 0.277,
#   'compound': 0.8074,
#   'label': 'nan while i arrived early  they fit me in  asked thoughtful and concerned questions and helped solve my problem  and offered me cold water on a hot day  everything was great '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.904,
#   'pos': 0.096,
#   'compound': 0.5106,
#   'label': 'nan dr gadmack took time to listen and discuss my concerns with me to come up with a treatment plan i am comfortable with   she also provided additional information to read  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan dr  song listens to what you have to say and is very polite and professional  nan'},
#  {'neg': 0.0,
#   'neu': 0.69,
#   'pos': 0.31,
#   'compound': 0.8008,
#   'label': 'nan very professional  efficient and the doctor listened to what i had to say  which was great  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.538,
#   'pos': 0.462,
#   'compound': 0.7184,
#   'label': 'nice and friendly  seems to be knowledgeable  nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.145,
#   'neu': 0.832,
#   'pos': 0.023,
#   'compound': -0.9324,
#   'label': 'the place is dirty  there is unprofessional stuff at the front desk  trophy with a poop emoji hat  wtf   my partner and i were seen in the same room together  hipaa still applies even if you acirc  euro  trade re married   the door to our room was kept open until the tech was actually there to run the tests  why not closed for our privacy    she measured our heights wrong  we checked when we got home   in general it was a very unprofessional experience that i will never be repeating if i can possibly help it  saw us promptly see previous statement'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan answered all questions and listened nothing that i can think of '},
#  {'neg': 0.1,
#   'neu': 0.701,
#   'pos': 0.199,
#   'compound': 0.4019,
#   'label': 'nan my doctor listens to likes and dislikes when prescribing medications to ensure i can still work  just running a little late'},
#  {'neg': 0.066,
#   'neu': 0.776,
#   'pos': 0.158,
#   'compound': 0.4754,
#   'label': 'nan everything went well   it was the first time i had seen this provider  since i just switched to paladina  and i was extremely pleased   there were no negatives '},
#  {'neg': 0.0,
#   'neu': 0.75,
#   'pos': 0.25,
#   'compound': 0.4585,
#   'label': 'nan explain step by step did nothing negative at all'},
#  {'neg': 0.0,
#   'neu': 0.842,
#   'pos': 0.158,
#   'compound': 0.4939,
#   'label': 'nan asked a complete relevant history  set a plan in place for future care  phone appointment was late '},
#  {'neg': 0.0,
#   'neu': 0.585,
#   'pos': 0.415,
#   'compound': 0.915,
#   'label': 'nan i was treated with kindness and respect  they were very helpful  explained everything for me until i understood   very comfortable nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.728,
#   'pos': 0.272,
#   'compound': 0.8777,
#   'label': 'nan all of the staff  especially dr  fairbanks were very friendly  patient  and courteous  i felt comfortable asking questions and speaking to everyone  despite it being my first visit  nan'},
#  {'neg': 0.0,
#   'neu': 0.44,
#   'pos': 0.56,
#   'compound': 0.7475,
#   'label': 'nan great  eth  yuml  lsquo   no complaints'},
#  {'neg': 0.053,
#   'neu': 0.788,
#   'pos': 0.159,
#   'compound': 0.7316,
#   'label': 'nan the provider took his time and i felt that he really listened and was interested in my goals for my health  the staff was very friendly and helpful  the website showed an address that wasn     t current along with my appointment  so i went to the wrong location first '},
#  {'neg': 0.0,
#   'neu': 0.843,
#   'pos': 0.157,
#   'compound': 0.6249,
#   'label': 'nan adressed most medical issues i had right in the office  medical providers keep changing  leaving  canon city  co        location would be great'},
#  {'neg': 0.0,
#   'neu': 0.429,
#   'pos': 0.571,
#   'compound': 0.8402,
#   'label': 'nan always amazing love the whole staff na'},
#  {'neg': 0.078,
#   'neu': 0.805,
#   'pos': 0.118,
#   'compound': 0.34,
#   'label': 'nan my appointments have always been great  the only time i had a problem is when i was there for blood work and the ma could not find my vein'},
#  {'neg': 0.0,
#   'neu': 0.905,
#   'pos': 0.095,
#   'compound': 0.2732,
#   'label': 'nan i was a little early to my appointment and they took me right in  everything went well for my appointment '},
#  {'neg': 0.0,
#   'neu': 0.842,
#   'pos': 0.158,
#   'compound': 0.9062,
#   'label': 'nan this visit was recommended following a brief hospital stay   both kim and kathleen listened to the events that happened and examined me   extra care was taken since i am undergoing chemo during the covid pandemic   kathleen shared that they took extra care to clean the room that i was going to be in for the visit   i did not encounter or have contact with anyone else during the visit except for kim and kathleen  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan listen to me nan'},
#  {'neg': 0.0,
#   'neu': 0.658,
#   'pos': 0.342,
#   'compound': 0.8535,
#   'label': 'nan all  office staff was very courteous  dr watson seems to be very compassionate and knowledgeable doctor i have no complaints'},
#  {'neg': 0.0,
#   'neu': 0.61,
#   'pos': 0.39,
#   'compound': 0.4939,
#   'label': 'nan friendly and knowledgeable staff nan'},
#  {'neg': 0.0,
#   'neu': 0.942,
#   'pos': 0.058,
#   'compound': 0.4549,
#   'label': 'from the front desk to the nurse to the exam room with the certified physician  i was attended to thoroughly and thoughtfully  the staff were following up with patients as needed and doing it in the time it would take in a professional environment  nothing  all needs were addressed '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.917,
#   'pos': 0.083,
#   'compound': 0.3708,
#   'label': 'nan kim was very interested in my history and in ensuring my concerns were addressed wait time was longer than expected  but that was a result of the patient prior to me consuming more that the time expected for his visit'},
#  {'neg': 0.052,
#   'neu': 0.849,
#   'pos': 0.099,
#   'compound': 0.3919,
#   'label': 'quick appointment availability and provider was helpful  but was confused about how the phone call appointment would work  knowledgeable and nice provider  quick availability it was not communicated in advance how the phone call appointment would work  specifically  that they would call me and that they may be a bit late'},
#  {'neg': 0.0,
#   'neu': 0.882,
#   'pos': 0.118,
#   'compound': 0.3716,
#   'label': 'nan the personal connection and interaction with the staff was awesome  wait time was a little long but not understandable '},
#  {'neg': 0.154,
#   'neu': 0.846,
#   'pos': 0.0,
#   'compound': -0.5765,
#   'label': 'the doctor is not very interested or involved  it was fast tried talking to the doctor about concerns and she didnt seem interested  she was quick with everything '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.065,
#   'neu': 0.873,
#   'pos': 0.063,
#   'compound': -0.0129,
#   'label': 'nan being on time  attended my questions  resolve quickly my illness  previous explication about how to enter to the virtual appointment  but it was a little intuitive '},
#  {'neg': 0.0,
#   'neu': 0.829,
#   'pos': 0.171,
#   'compound': 0.765,
#   'label': 'nan from start to finish the staff were friendly and kind  they were polite  i showed up a little early and they were able to usher me on in  can     t think of anything '},
#  {'neg': 0.0,
#   'neu': 0.82,
#   'pos': 0.18,
#   'compound': 0.8354,
#   'label': 'nan the pa  jennifer  had gone through my medical history and was thoroughly prepared to address anything that might need to be looked at in the future  i appreciate the level of concern to know my history  even though i have never met her  very good  everything was fine '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.644,
#   'pos': 0.356,
#   'compound': 0.8344,
#   'label': 'nan everyone is very professional and nice   i always have a good experience   keep up the good work  nan'},
#  {'neg': 0.0,
#   'neu': 0.855,
#   'pos': 0.145,
#   'compound': 0.4703,
#   'label': 'nan ashley was very patient and helpful  this was my first appointment and i had lots of questions  nothing'},
#  {'neg': 0.1,
#   'neu': 0.794,
#   'pos': 0.106,
#   'compound': 0.329,
#   'label': 'nan very timely   easy to get in and out quickly very friendly  i think the scheduling of the flu shot was difficult because although i am covered under my district rsquo s insurance  they did not want inactive personnel to come into schools to receive the shot   it was miscommunication between the district and paladina '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.872,
#   'pos': 0.128,
#   'compound': 0.3612,
#   'label': 'nan the doctor listened to my issue and i felt like he gave me the appropriate guidance nan'},
#  {'neg': 0.065,
#   'neu': 0.935,
#   'pos': 0.0,
#   'compound': -0.3724,
#   'label': 'nan i was in for a strep test because my wife and   children both had it but i did not   the np explained the pros cons of taking the test and we ultimately decided to take it  nan'},
#  {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'label': 'nan attentiveness  explaining my symptoms and a treatment plan  getting back to me the very next morning with test results  and fitting me into the schedule last minute nothing'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.625,
#   'pos': 0.375,
#   'compound': 0.9116,
#   'label': 'it was clean  the doctor  amp  recipients was friendly it was quick    and very friendly staff  the doctor was very knowledgeable it was very good'},
#  {'neg': 0.0,
#   'neu': 0.706,
#   'pos': 0.294,
#   'compound': 0.3612,
#   'label': 'nan made me feel at ease  na'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0,
#   'neu': 0.72,
#   'pos': 0.28,
#   'compound': 0.7506,
#   'label': 'liked the one on one with the doctor and you feel like they real are concerned about your well being nan nan'},
#  {'neg': 0.0,
#   'neu': 0.634,
#   'pos': 0.366,
#   'compound': 0.9136,
#   'label': 'nan dr martin takes his time and takes it with great care and patience  his staff reflects this same attitude and it is well appreciated  nan'},
#  {'neg': 0.0,
#   'neu': 0.488,
#   'pos': 0.512,
#   'compound': 0.7384,
#   'label': 'nan everything     s so awesome  nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.066,
#   'neu': 0.857,
#   'pos': 0.077,
#   'compound': 0.34,
#   'label': 'i love paladina   the only issues i have is when i try to schedule an appointment at the location closest to me when i am sick that particular location is not always open   sometimes the doctor is at another location   and i thought i signed up for this plan due to convenience   not always that convenient if i would have to drive    miles out of my way for an apt when i am sick  doctor and staff are pleasant and professional   no waiting on appointments   clean facility  too much pre paperwork   i am always filling out the same thing when i go in   maybe something to send in advance of appointment or the old documents to verify for current status '},
#  {'neg': 0.042,
#   'neu': 0.699,
#   'pos': 0.259,
#   'compound': 0.9633,
#   'label': 'the clinics are hit and miss   i received excellent care from dr  masterson at the broomfield  co clinic however the arvada  co clinic i would not recommend to anyone  the doctor was kind and caring   she went over all of my past blood work for my chronic diseases and talked to me about that as well as taking new blood work and completing my female wellness exams  everything was great '},
#  {'neg': 0.0,
#   'neu': 0.553,
#   'pos': 0.447,
#   'compound': 0.9734,
#   'label': 'nan got in quickly and was treated very well  nurse was very kind and caring  doctor answered all my questions and was very caring  paladina health is the best  my appointment was perfect  thank you paladina   '},
#  {'neg': 0.024,
#   'neu': 0.805,
#   'pos': 0.17,
#   'compound': 0.8316,
#   'label': 'nan intake was helpful  polite and courteous   i had an appointment the next day when i called   i was seen on time   dr  goreman took time to explain his thoughts   i have not had that thorough of an appointment  ever  sorry  dont have anything that needs improvement '},
#  {'neg': 0.0,
#   'neu': 0.872,
#   'pos': 0.128,
#   'compound': 0.4215,
#   'label': 'nan it was nice not to spend an hour in the waiting room with a bunch of other people nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.195,
#   'neu': 0.725,
#   'pos': 0.08,
#   'compound': -0.8413,
#   'label': 'was not greeted at the waiting area  doctor had poor social interactions bedside manner  was unsure what to do when leaving appointment as there was no one at the desk again  so i just left the office  scheduled me with a doctor on a day i wasn     t feeling well  poor bedside manner  poor office interaction with patient  very little help offered from doctor to patient '},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0, 'label': 'nan nan nan'},
#  {'neg': 0.137,
#   'neu': 0.737,
#   'pos': 0.126,
#   'compound': -0.0534,
#   'label': 'nan i received my flu shot   everything went very well  i can     t think of anything '},
#  {'neg': 0.0,
#   'neu': 0.489,
#   'pos': 0.511,
#   'compound': 0.9565,
#   'label': 'nan i love love love dr  everette  she is very thorough and addresses all of my concerns  did everything great '},
#  {'neg': 0.271,
#   'neu': 0.729,
#   'pos': 0.0,
#   'compound': -0.3818,
#   'label': 'nan new patient  exam and flu shot nan'},
#  {'neg': 0.0,
#   'neu': 0.815,
#   'pos': 0.185,
#   'compound': 0.3612,
#   'label': 'i like the service this program program provides adreesed my concerns nothing'},
#  {'neg': 0.0,
#   'neu': 0.646,
#   'pos': 0.354,
#   'compound': 0.8519,
#   'label': 'nan my doctor was very thorough and answered all my questions  the staff was friendly and provided good care  nan'},
#  {'neg': 0.0,
#   'neu': 0.682,
#   'pos': 0.318,
#   'compound': 0.7906,
#   'label': 'nan my doctor asked lots of questions and the staff was pleasant  n a   it was excellent'},
#  ...]

# %%
# Creating a new dataframe to showing the new data side by side with the previous one
# We are only interested in the compunt score (aggregated score)
reason_score_reviews['polarity_score'] = pd.DataFrame(reason_score_polarity_score_list)['compound']
reason_score_reviews['positive_score'] = pd.DataFrame(reason_score_polarity_score_list)['pos']
reason_score_reviews['negative_score'] = pd.DataFrame(reason_score_polarity_score_list)['neu']

reason_score_reviews[['polarity_score']] = reason_score_reviews[['polarity_score']].fillna(0)
reason_score_reviews[['positive_score']] = reason_score_reviews[['positive_score']].fillna(0)
reason_score_reviews[['negative_score']] = reason_score_reviews[['negative_score']].fillna(0)

# %%
reason_score_reviews['polarity_score'].head()
# Out:
# 0    0.8874
# 1    0.0000
# 2    0.0000
# 3    0.0000
# 4    0.9042
# Name: polarity_score, dtype: float64

# %%
data['polarity_score'] = reason_score_reviews['polarity_score']

# %%
data.to_csv('data_with_polarity.csv',index=False)

# %%
reason_score_reviews.head()
# Out:
#             REVIEW_ID           MEMBER_ID                        NPSCLINIC__C  \
# 0  a2p1U000000RoK0QAK  0011U00000riNolQAE        Arvada City of Arvada Clinic
# 1  a2p3g000000LAe2AAG  0011U00000riuzfQAA  Seven Hills Lombardo Center Clinic
# 2  a2p3g000000LAenAAG  0011U00000rieIYQAY           Monroe Campus Park Clinic
# 3  a2p1U000000l8FEQAY  0011U00000rjZH9QAM       Akron-White Pond Drive Clinic
# 4  a2p1U000000Rv9VQAS  0011U00000rjesHQAQ      Euclid Lincoln Electric Clinic
#
#   APPOINTMENTPROVIDER__C SURVEYDATE__C SURVEY_MONTH SURVEY_YEAR  \
# 0                    NaN    07-09-2018       Jul-18        2018
# 1     0031U00000olN5ZQAU    07-01-2020       Jul-20        2020
# 2     0031U00000olN7aQAE     6/27/2020       Jun-20        2020
# 3     0031U00000olN71QAE    10/25/2019       Oct-19        2019
# 4     0031U00000olN8YQAU     9/24/2019       Sep-19        2019
#
#    SURVEYNUMBER__C  NPS                                  REASONNPSSCORE__C  \
# 0            20536   10                                                NaN
# 1      11752005028    5                                                NaN
# 2      11737091171   10                                                NaN
# 3            31790   10                                                NaN
# 4            31283    8  I like the facility and the doctor.  I felt co...
#
#    ... positive_score negative_score sentiment sentiment_label  nps_label  \
# 0  ...          0.677          0.323         1        Positive   Promoter
# 1  ...          0.000          1.000         0         Neutral  Detractor
# 2  ...          0.000          1.000         0         Neutral   Promoter
# 3  ...          0.000          1.000         0         Neutral   Promoter
# 4  ...          0.169          0.831         1        Positive    Passive
#
#                           CLIENT NAME                  PARENT CLIENT NAME  \
# 0                   State of Colorado                   State of Colorado
# 1  Cleveland Bakers & Teamsters (CBT)  Cleveland Bakers & Teamsters (CBT)
# 2                        Union County                        Union County
# 3  Cleveland Bakers & Teamsters (CBT)  Cleveland Bakers & Teamsters (CBT)
# 4                    Lincoln Electric                    Lincoln Electric
#
#      PARENT_CLIENT_ID MEMBER_DOB MEMBER_STREET
# 0  0011U00000rhpLpQAI        NaN           NaN
# 1  0011U00000rhpN6QAI        NaN           NaN
# 2  0011U00000rhpLjQAI        NaN           NaN
# 3  0011U00000rhpN6QAI        NaN           NaN
# 4  0011U00000rhpMwQAI        NaN           NaN
#
# [5 rows x 108 columns]

# %%
# Creating a function to classify sentiment scores based on the polarity score
def sentiment_label(row):
    if row['polarity_score'] > 0 :
        sentiment_score = "Positive" # Positive sentiment
    if row['polarity_score'] < 0 :
        sentiment_score = "Negative" # Negative sentiment
    if row['polarity_score'] == 0:
        sentiment_score = "Neutral" # Neutral sentiment
    return sentiment_score

def sentiment(row):
    if row['polarity_score'] > 0 :
        sentiment_score = 1 # Positive sentiment
    if row['polarity_score'] < 0 :
        sentiment_score = -1 # Negative sentiment
    if row['polarity_score'] == 0:
        sentiment_score = 0 # Neutral sentiment
    return sentiment_score

# %%
# Creating a new column which will contain sentiment scores based on the polarity score of each feedback
reason_score_reviews['sentiment'] = reason_score_reviews.apply(sentiment, axis=1)
reason_score_reviews['sentiment_label'] = reason_score_reviews.apply(sentiment_label, axis=1)

# %%
# Fixing polarity scores and related labels
reason_score_reviews.loc[reason_score_reviews['reviews'].str.match('^(?=.*rude)|(?=.*worst)|(?=.*frustrated)|(?=.*angry)|(?=.*terrible)|(?=.*disrespectful)|(?=.*irresponsibly)|(?=.*irresponsible)|(?=.*improper)|(?=.*wasted)|(?=.*violate)|(?=.*violations)|(?=.*aren t worth)|(?=.*undress)|(?=.*didnt treat me)|(?=.*horrible)|(?=kill)|(?=.*danger)|(?=.*dangerous)|(?=rough)|(?=.*dismissed)|(?=.*upsetting)|(?=.*out of line)|(?=.*uncomfortable)|(?=.*can t breathe)|(?=.*breast)|(?=.*was misdiagnosed)|(?=.*did not examine me)|(?=.*forced to participate)|(?=.*forced into it)'), 'sentiment'] = 2
reason_score_reviews.loc[reason_score_reviews['reviews'].str.match('^(?=.*rude)|(?=.*worst)|(?=.*frustrated)|(?=.*angry)|(?=.*terrible)|(?=.*disrespectful)|(?=.*irresponsibly)|(?=.*irresponsible)|(?=.*improper)|(?=.*wasted)|(?=.*violate)|(?=.*violations)|(?=.*aren t worth)|(?=.*undress)|(?=.*didnt treat me)|(?=.*horrible)|(?=kill)|(?=.*danger)|(?=.*dangerous)|(?=rough)|(?=.*dismissed)|(?=.*upsetting)|(?=.*out of line)|(?=.*uncomfortable)|(?=.*can t breathe)|(?=.*breast)|(?=.*was misdiagnosed)|(?=.*did not examine me)|(?=.*forced to participate)|(?=.*forced into it)'), 'sentiment_label'] = 'Extreme'
reason_score_reviews.loc[(reason_score_reviews['polarity_score']>0) & (reason_score_reviews['sentiment_label']=='Extreme'), 'polarity_score']*=-1

reason_score_reviews.loc[(reason_score_reviews['NPS']>=7) & (reason_score_reviews['sentiment_label']=='Negative'), 'sentiment']=1
reason_score_reviews.loc[(reason_score_reviews['NPS']>=7) & (reason_score_reviews['sentiment_label']=='Negative'), 'sentiment_label']='Positive'
reason_score_reviews.loc[(reason_score_reviews['NPS']>=7) & (reason_score_reviews['polarity_score']<0), 'polarity_score']*=-1

reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*good)|(?=.*great)|(?=.*awesome)|(?=.*very much)|(?=.*friendly)|(?=.*appreciate)|(?=.*compassionate)|(?=.*went well)|(?=.*very thorough)|(?=.*assisted)|(?=.*easy)|(?=.*enjoyed)|(?=.*i like)|(?=.*i liked)|(?=.*nice)|(?=.*love)|(?=.*caring)|(?=.*impressed)|(?=.*knowledgeable)|(?=.*very comfortable)|(?=.*very professional)|(?=.*achieved)|(?=.*courteous)|(?=.*listen to what i had to say)|(?=.*right amount of time)|(?=.*on time)|(?=.*personable)|(?=.*efficient)|(?=.*fantastic)|(?=.*punctual)|(?=.*go over issues)|(?=.*got me in same day)|(?=.*all my concerns)|(?=.*everything)|(?=.*sat and talked)') & (reason_score_reviews['NPS']>=5), 'sentiment'] = 1
reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*good)|(?=.*great)|(?=.*awesome)|(?=.*very much)|(?=.*friendly)|(?=.*appreciate)|(?=.*compassionate)|(?=.*went well)|(?=.*very thorough)|(?=.*assisted)|(?=.*easy)|(?=.*enjoyed)|(?=.*i like)|(?=.*i liked)|(?=.*nice)|(?=.*love)|(?=.*caring)|(?=.*impressed)|(?=.*knowledgeable)|(?=.*very comfortable)|(?=.*very professional)|(?=.*achieved)|(?=.*courteous)|(?=.*listen to what i had to say)|(?=.*right amount of time)|(?=.*on time)|(?=.*personable)|(?=.*efficient)|(?=.*fantastic)|(?=.*punctual)|(?=.*go over issues)|(?=.*got me in same day)|(?=.*all my concerns)|(?=.*everything)|(?=.*sat and talked)') & (reason_score_reviews['NPS']>=5), 'sentiment_label'] = 'Positive'
reason_score_reviews.loc[(reason_score_reviews['polarity_score']<0) & (reason_score_reviews['sentiment_label']=='Positive'), 'polarity_score']*=-1

# %%
reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*wasn t treated)|(?=.*waited)|(?=.*not as caring)|(?=.*did not think)|(?=.*didn t think)|(?=.*did not get)|(?=.*didn t get)|(?=.*felt rushed)|(?=.*was rushed)|(?=.*seemed rushed)|(?=.*did not fix)|(?=.*didn t fix)|(?=.*didn t listen)|(?=.*did not listen)|(?=.*ignored)|(?=.*unprofessional)|(?=.*don t think)|(?=.*do not think)|(?=.*waiting)|(?=.*talked too much)|(?=.*please)|(?=.*took longer)|(?=.*didn t show)|(?=.*did not show)|(?=.*never)|(?=.*difficult)|(?=.*unable)|(?=.*didn t look)|(?=.*did not look)|(?=.*not being treated)|(?=.*was not)|(?=.*confused)|(?=.*did not recognize)|(?=.*didn t recognize)|(?=.*do not like)|(?=.*don t like)|(?=.*wasn t greeted)|(?=.*was not greeted)|(?=.*need to improve)|(?=.*no one)|(?=.*lacking)|(?=.*no solution)|(?=.*didn t understand)|(?=.*did not understand)|(?=.*unorganized)|(?=.*my issues)|(?=.*without)|(?=.*no follow up)|(?=.*doesn t seem)|(?=.*does not seem)|(?=.*would not call)|(?=.*wouldn t call)|(?=.*were not)|(?=.*not very)|(?=.*not answered)|(?=.*no answer)|(?=.*conflict)|(?=.*didnt treat)|(?=.*didn t treat)|(?=.*did not treat)|(?=.*lack)|(?=.*lacking)|(?=.*lacked)|(?=.*need to)|(?=.*not near as caring)|(?=.*already expressed)|(?=.*far away)') & (reason_score_reviews['NPS']<=4), 'sentiment'] = -1
reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*wasn t treated)|(?=.*waited)|(?=.*not as caring)|(?=.*did not think)|(?=.*didn t think)|(?=.*did not get)|(?=.*didn t get)|(?=.*felt rushed)|(?=.*was rushed)|(?=.*seemed rushed)|(?=.*did not fix)|(?=.*didn t fix)|(?=.*didn t listen)|(?=.*did not listen)|(?=.*ignored)|(?=.*unprofessional)|(?=.*don t think)|(?=.*do not think)|(?=.*waiting)|(?=.*talked too much)|(?=.*please)|(?=.*took longer)|(?=.*didn t show)|(?=.*did not show)|(?=.*never)|(?=.*difficult)|(?=.*unable)|(?=.*didn t look)|(?=.*did not look)|(?=.*not being treated)|(?=.*was not)|(?=.*confused)|(?=.*did not recognize)|(?=.*didn t recognize)|(?=.*do not like)|(?=.*don t like)|(?=.*wasn t greeted)|(?=.*was not greeted)|(?=.*need to improve)|(?=.*no one)|(?=.*lacking)|(?=.*no solution)|(?=.*didn t understand)|(?=.*did not understand)|(?=.*unorganized)|(?=.*my issues)|(?=.*without)|(?=.*no follow up)|(?=.*doesn t seem)|(?=.*does not seem)|(?=.*would not call)|(?=.*wouldn t call)|(?=.*were not)|(?=.*not very)|(?=.*not answered)|(?=.*no answer)|(?=.*conflict)|(?=.*didnt treat)|(?=.*didn t treat)|(?=.*did not treat)|(?=.*lack)|(?=.*lacking)|(?=.*lacked)|(?=.*need to)|(?=.*not near as caring)|(?=.*already expressed)|(?=.*far away)') & (reason_score_reviews['NPS']<=4), 'sentiment_label'] = 'Negative'
reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*wasn t treated)|(?=.*waited)|(?=.*not as caring)|(?=.*did not think)|(?=.*didn t think)|(?=.*did not get)|(?=.*didn t get)|(?=.*felt rushed)|(?=.*was rushed)|(?=.*seemed rushed)|(?=.*did not fix)|(?=.*didn t fix)|(?=.*didn t listen)|(?=.*did not listen)|(?=.*ignored)|(?=.*unprofessional)|(?=.*don t think)|(?=.*do not think)|(?=.*waiting)|(?=.*talked too much)|(?=.*please)|(?=.*took longer)|(?=.*didn t show)|(?=.*did not show)|(?=.*never)|(?=.*difficult)|(?=.*unable)|(?=.*didn t look)|(?=.*did not look)|(?=.*not being treated)|(?=.*was not)|(?=.*confused)|(?=.*did not recognize)|(?=.*didn t recognize)|(?=.*do not like)|(?=.*don t like)|(?=.*wasn t greeted)|(?=.*was not greeted)|(?=.*need to improve)|(?=.*no one)|(?=.*lacking)|(?=.*no solution)|(?=.*didn t understand)|(?=.*did not understand)|(?=.*unorganized)|(?=.*my issues)|(?=.*without)|(?=.*no follow up)|(?=.*doesn t seem)|(?=.*does not seem)|(?=.*would not call)|(?=.*wouldn t call)|(?=.*were not)|(?=.*not very)|(?=.*not answered)|(?=.*no answer)|(?=.*conflict)|(?=.*didnt treat)|(?=.*didn t treat)|(?=.*did not treat)|(?=.*lack)|(?=.*lacking)|(?=.*lacked)|(?=.*need to)|(?=.*not near as caring)|(?=.*already expressed)|(?=.*far away)|(?=.*dirty)|(?=.*don t have resources)|(?=.*dont lie)|(?=.*too long)|(?=.*forgot)|(?=.*give proper)|(?=.*not treating)|(?=.*worthless)|(?=.*doesn t look well)|(?=.*don t get)|(?=.*way to long)|(?=.*not willing)|(?=.*no examination)|(?=.*failed)|(?=.*didn t follow up)|(?=.*doesn t follow up)|(?=.*was cold)|(?=.*little compassion)|(?=.*inexperienced)|(?=.*didn t even)|(?=.*needs to be cleaned)|(?=.*forgot to call)|(?=.*did not hear)|(?=.*superficial)|(?=.*afraid to touch)|(?=.*did not trust)|(?=.*far too long)|(?=.*don t have any resources)|(?=.*not happy)|(?=.*made me wait)|(?=.*awful)|(?=.*dirty)|(?=.*nobody grteeted)|(?=.*won t call)|(?=.*did not work)|(?=.*entire problem was)|(?=.*didn t even acknowledge)|(?=.*doesn t care)|(?=.*incompetent)|(?=.*not knowledgeable)|(?=.*didn t make appointment right)|(?=.*should not have)|(?=.*had to wait awhile)|(?=.*way too long)|(?=.*frustrating)|(?=.*they don t do)|(?=.*than the person you have hired)|(?=.*wasn t very clean)|(?=.*made me very sick)|(?=.*we were told)|(?=.*what is going on)|(?=.*don t recommend)|(?=.*only thing they cared about)|(?=.*did not seem to care)|(?=.*pretty disappointed)|(?=.*mess up my medicine)|(?=.*very demeaning)|(?=.*unfriendly)|(?=.*very disappointed)|(?=.*didn t have any good)|(?=.*wasn t much true interest)|(?=.*not acceptable)|(?=.*does not listen)|(?=.*did not listen)|(?=.*would not refill)|(?=.*not happening)|(?=.*not great)|(?=.*new very little)|(?=.*to long of a time)|(?=.*poor instructions)|(?=.*poor service)|(?=.*was charged an excessive amount)|(?=.*thrilled i was able)'), 'sentiment'] = -1
reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*wasn t treated)|(?=.*waited)|(?=.*not as caring)|(?=.*did not think)|(?=.*didn t think)|(?=.*did not get)|(?=.*didn t get)|(?=.*felt rushed)|(?=.*was rushed)|(?=.*seemed rushed)|(?=.*did not fix)|(?=.*didn t fix)|(?=.*didn t listen)|(?=.*did not listen)|(?=.*ignored)|(?=.*unprofessional)|(?=.*don t think)|(?=.*do not think)|(?=.*waiting)|(?=.*talked too much)|(?=.*please)|(?=.*took longer)|(?=.*didn t show)|(?=.*did not show)|(?=.*never)|(?=.*difficult)|(?=.*unable)|(?=.*didn t look)|(?=.*did not look)|(?=.*not being treated)|(?=.*was not)|(?=.*confused)|(?=.*did not recognize)|(?=.*didn t recognize)|(?=.*do not like)|(?=.*don t like)|(?=.*wasn t greeted)|(?=.*was not greeted)|(?=.*need to improve)|(?=.*no one)|(?=.*lacking)|(?=.*no solution)|(?=.*didn t understand)|(?=.*did not understand)|(?=.*unorganized)|(?=.*my issues)|(?=.*without)|(?=.*no follow up)|(?=.*doesn t seem)|(?=.*does not seem)|(?=.*would not call)|(?=.*wouldn t call)|(?=.*were not)|(?=.*not very)|(?=.*not answered)|(?=.*no answer)|(?=.*conflict)|(?=.*didnt treat)|(?=.*didn t treat)|(?=.*did not treat)|(?=.*lack)|(?=.*lacking)|(?=.*lacked)|(?=.*need to)|(?=.*not near as caring)|(?=.*already expressed)|(?=.*far away)|(?=.*dirty)|(?=.*don t have resources)|(?=.*dont lie)|(?=.*too long)|(?=.*forgot)|(?=.*give proper)|(?=.*not treating)|(?=.*worthless)|(?=.*doesn t look well)|(?=.*don t get)|(?=.*way to long)|(?=.*not willing)|(?=.*no examination)|(?=.*failed)|(?=.*didn t follow up)|(?=.*doesn t follow up)|(?=.*was cold)|(?=.*little compassion)|(?=.*inexperienced)|(?=.*didn t even)|(?=.*needs to be cleaned)|(?=.*forgot to call)|(?=.*did not hear)|(?=.*superficial)|(?=.*afraid to touch)|(?=.*did not trust)|(?=.*far too long)|(?=.*don t have any resources)|(?=.*not happy)|(?=.*made me wait)|(?=.*awful)|(?=.*dirty)|(?=.*nobody grteeted)|(?=.*won t call)|(?=.*did not work)|(?=.*entire problem was)|(?=.*didn t even acknowledge)|(?=.*doesn t care)|(?=.*incompetent)|(?=.*not knowledgeable)|(?=.*didn t make appointment right)|(?=.*should not have)|(?=.*had to wait awhile)|(?=.*way too long)|(?=.*frustrating)|(?=.*they don t do)|(?=.*than the person you have hired)|(?=.*wasn t very clean)|(?=.*made me very sick)|(?=.*we were told)|(?=.*what is going on)|(?=.*don t recommend)|(?=.*only thing they cared about)|(?=.*did not seem to care)|(?=.*pretty disappointed)|(?=.*mess up my medicine)|(?=.*very demeaning)|(?=.*unfriendly)|(?=.*very disappointed)|(?=.*didn t have any good)|(?=.*wasn t much true interest)|(?=.*not acceptable)|(?=.*does not listen)|(?=.*did not listen)|(?=.*would not refill)|(?=.*not happening)|(?=.*not great)|(?=.*new very little)|(?=.*to long of a time)|(?=.*poor instructions)|(?=.*poor service)|(?=.*was charged an excessive amount)|(?=.*thrilled i was able)'), 'sentiment_label'] = 'Negative'
reason_score_reviews.loc[(reason_score_reviews['polarity_score']>0) & (reason_score_reviews['sentiment_label']=='Negative'), 'polarity_score']*=-1

reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*amazing)|(?=.*can t think of anything)|(?=.*completely satisfied)|(?=.*no complaints)|(?=.*perfect)|(?=.*was fine)|(?=.*was nice)|(?=.*very happy)|(?=.*well communication)|(?=.*enough time with me)|(?=.*not a single thing)|(?=.*couldn t ask for anything more)|(?=.*very satisfied)|(?=.*nothing to say)|(?=.*nothing to report)|(?=.*very pleasant)|(?=.*was well)|(?=.*completely happy)|(?=.*was pleased)|(?=.*all employees use)|(?=.*super nice)|(?=.*never had a doctor spend)|(?=.*very pleased)|(?=.*it was okay)|(?=.*was quick)|(?=.*convenient high quality)|(?=.*very welcoming)|(?=.*provide great care)|(?=.*very nice)|(?=.*treat you like family)|(?=.*always on time)|(?=.*very helpful)|(?=.*i am fortunate)|(?=.*best coarse of action)|(?=.*very convenient)|(?=.*i iike the doctor)|(?=.*great service)|(?=.*wasn t too long)|(?=.*extremely convenient)|(?=.*service is good)|(?=.*i like being able to)|(?=.*overall i liked)|(?=.*paladinais the city s health)'), 'sentiment'] = 1
reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=.*amazing)|(?=.*can t think of anything)|(?=.*completely satisfied)|(?=.*no complaints)|(?=.*perfect)|(?=.*was fine)|(?=.*was nice)|(?=.*very happy)|(?=.*well communication)|(?=.*enough time with me)|(?=.*not a single thing)|(?=.*couldn t ask for anything more)|(?=.*very satisfied)|(?=.*nothing to say)|(?=.*nothing to report)|(?=.*very pleasant)|(?=.*was well)|(?=.*completely happy)|(?=.*was pleased)|(?=.*all employees use)|(?=.*super nice)|(?=.*never had a doctor spend)|(?=.*very pleased)|(?=.*it was okay)|(?=.*was quick)|(?=.*convenient high quality)|(?=.*very welcoming)|(?=.*provide great care)|(?=.*very nice)|(?=.*treat you like family)|(?=.*always on time)|(?=.*very helpful)|(?=.*i am fortunate)|(?=.*best coarse of action)|(?=.*very convenient)|(?=.*i iike the doctor)|(?=.*great service)|(?=.*wasn t too long)|(?=.*extremely convenient)|(?=.*service is good)|(?=.*i like being able to)|(?=.*overall i liked)|(?=.*paladinais the city s health)'), 'sentiment_label'] = 'Positive'
reason_score_reviews.loc[reason_score_reviews['reviews'].str.contains('^(?=convenient)') & (reason_score_reviews['NPS']==6), 'sentiment_label'] = 'Positive'
reason_score_reviews.loc[(reason_score_reviews['polarity_score']<0) & (reason_score_reviews['sentiment_label']=='Positive'), 'polarity_score']*=-1

reason_score_reviews.loc[(reason_score_reviews['NPS']>=9) & (reason_score_reviews['NPS']<=10), 'nps_label'] = 'Promoter'
reason_score_reviews.loc[(reason_score_reviews['NPS']>=7) & (reason_score_reviews['NPS']<=8), 'nps_label'] = 'Passive'
reason_score_reviews.loc[reason_score_reviews['NPS']<=6, 'nps_label'] = 'Detractor'
# Out:
# Promoter     21421
# Passive       3068
# Detractor     1411
# Name: nps_label, dtype: int64

# %%
#reason_score_reviews['nps_label'].value_counts()

# %%
#reason_score_reviews["sentiment_label"].value_counts()

# %%
client_df = pd.read_csv('Client Master Clean Data_Client Master List_clean.csv')

# %%
c_df = client_df[['CLIENT NAME', 'PARENT CLIENT NAME', 'CLIENT_ID','PARENT_CLIENT_ID']]

# %%
c_df = c_df.drop_duplicates(subset = ['CLIENT_ID'],keep=False)

# %%
after_client_join = reason_score_reviews.merge(c_df, on='CLIENT_ID', how='left')

# %%
after_client_join.to_csv('final_2018_2020.csv',index = False)
